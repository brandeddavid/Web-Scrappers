# %%
from bs4 import BeautifulSoup

# %%
from urllib.request import urlopen

# %%
url = 'http://www.dld-conference.com/speakers'

# %%
url_html = urlopen(url).read()

# %%
soup = BeautifulSoup(url_html,'html.parser')

# %%
speaker = soup.findAll('div', {"class":"circle"})

# %%
len(speaker)
# Out:
# 0

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
# <head>
# <meta charset="utf-8">
# <meta content="width=device-width,initial-scale=1" name="viewport">
# <meta content="ie=edge" http-equiv="x-ua-compatible">
# <title>DLD Conference: All speakers</title>
# <meta content="Overview of all speakers that spoke on DLD Conferences, a global conference network on innovation, digital, science and culture which connects business, creative and social leaders, opinion-formers..." name="description"/>
# <meta content="website" property="og:type"/>
# <meta content="DLD Conference: All speakers" property="og:title"/>
# <meta content="http://www.dld-conference.com/assets/dld_webteam-2c135cc313d2b5731707fd4a0e565dda.png" property="og:image"/>
# <meta content="Overview of all speakers that spoke on DLD Conferences, a global conference network on innovation, digital, science and culture which connects business, creative and social leaders, opinion-formers and investors for crossover conversation and inspiration." property="og:description"/>
# <meta content="DLD Conference" property="og:site_name"/>
# <meta content="http://www.dld-conference.com/speakers" property="og:url"/>
# <link href="http://www.dld-conference.com/speakers" rel="canonical"/>
# <script src="/assets/application-ebd1f1308b3eb1d20925f2b66c82feff.js"></script>
# <!-- Favicons -->
# <!-- For third-generation iPad with high-resolution Retina display: -->
# <link href="/favicons/apple-touch-icon-144x144-precomposed.png" rel="apple-touch-icon-precomposed" sizes="144x144">
# <!-- For iPhone with high-resolution Retina display: -->
# <link href="/favicons/apple-touch-icon-114x114-precomposed.png" rel="apple-touch-icon-precomposed" sizes="114x114">
# <!-- For first- and second-generation iPad: -->
# <link href="/favicons/apple-touch-icon-72x72-precomposed.png" rel="apple-touch-icon-precomposed" sizes="72x72">
# <!-- For non-Retina iPhone, iPod Touch, and Android 2.1+ devices: -->
# <link href="/favicons/apple-touch-icon-precomposed.png" rel="apple-touch-icon-precomposed">
# <!-- Default -->
# <link href="/favicons/favicon.ico" rel="shortcut icon"/>
# <link href="/assets/application-054d6944d2c4ef151c9308cbd3f919bf.css" media="all" rel="stylesheet"/>
# <meta content="authenticity_token" name="csrf-param"/>
# <meta content="X33+08gHYUTmxcbkki8w9tbqkN1bhFuOL2snqPdad1Q=" name="csrf-token"/>
# <script type="text/javascript">
#
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-37670162-1']);
#   _gaq.push(['_gat._anonymizeIp']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#
# </script>
# </link></link></link></link></meta></meta></meta></head>
# <body class="">
# <div class="side-menu-movable" id="side-menu">
# <div id="side-menu-content">
# <ul class="nav-links list-group">
# <li class="list-group-item "><a href="/conferences_overview">Conferences</a></li>
# <li class="list-group-item active"><a href="/speakers">Speaker</a></li>
# <li class="list-group-item "><a href="/videos">Media</a></li>
# <li class="list-group-item "><a href="/magazine">NEWS</a></li>
# <li class="list-group-item "><a href="/people/sign_in">MyDLD</a></li>
# <li class="list-group-item "><a href="/pages/about-us">About</a></li>
# </ul>
# <ul class="social-links list-inline text-right">
# <li>
# <a href="https://www.facebook.com/DLDconference" target="_blank">
# <i class="icon icon-social icon-facebook"></i>
# </a> </li>
# <li>
# <a href="https://twitter.com/dldconference" target="_blank">
# <i class="icon icon-social icon-twitter"></i>
# </a> </li>
# <li>
# <a href="https://instagram.com/dldconference/" target="_blank">
# <i class="icon icon-social icon-instagram"></i>
# </a> </li>
# <li>
# <a href="https://www.youtube.com/user/DLDconference" target="_blank">
# <i class="icon icon-social icon-youtube"></i>
# </a> </li>
# </ul>
# </div>
# </div>
# <div class="content-wrapper side-menu-movable">
# <div class="side-menu-movable" id="header">
# <header class="header-wrapper">
# <div class="top-bounce-fix"></div>
# <div class="container container-xs">
# <div class="left pull-left">
# <ul class="nav-links no-margin list-inline">
# <li class=""><a href="/conferences_overview">Conferences</a></li>
# <li class="active"><a href="/speakers">Speaker</a></li>
# <li class=""><a href="/videos">Media</a></li>
# </ul>
# </div>
# <div class="absolute-center text-center logo-wrapper">
# <a href="/">
# <img alt="Logo" class="logo display-inline-block" src="/assets/digital1/logos/logo-8bd1082808bdb232e189458057454f4e.svg"/>
# </a>
# </div>
# <div class="right pull-right">
# <ul class="nav-links no-margin list-inline">
# <li class=""><a href="/magazine">NEWS</a></li>
# <li class=""><a href="/people/sign_in">MyDLD</a></li>
# <li class=""><a href="/pages/about-us">About</a></li>
# </ul>
# </div>
# </div>
# <div class="far-right">
# <i class="icon icon-magnify pointer" id="search-button"></i>
# <ul class="social-links no-margin list-inline hidden-sm hidden-xs">
# <li>
# <a href="https://www.facebook.com/DLDconference" target="_blank">
# <i class="icon icon-social icon-facebook"></i>
# </a> </li>
# <li>
# <a href="https://twitter.com/dldconference" target="_blank">
# <i class="icon icon-social icon-twitter"></i>
# </a> </li>
# <li>
# <a href="https://instagram.com/dldconference/" target="_blank">
# <i class="icon icon-social icon-instagram"></i>
# </a> </li>
# <li>
# <a href="https://www.youtube.com/user/DLDconference" target="_blank">
# <i class="icon icon-social icon-youtube"></i>
# </a> </li>
# </ul>
# <i class="icon icon-menu pointer visible-sm visible-xs" id="side-menu-button"></i>
# </div>
# <div class="oval"></div>
# </header>
# <div class="search-container text-center">
# <div class="container container-xs no-padding relative-container">
# <form action="/search" method="get">
# <input id="search-input" name="q" placeholder="Search..." type="text">
# <button id="search-submit">
# <i class="icon icon-magnify pointer"></i>
# </button>
# </input></form>
# </div>
# </div>
# </div>
# <div id="content">
# <div class="consent-banner">
# <div class="cookies-eu">
# <span class="cookies-eu-content-holder">Cookies help us deliver our services. By using our services, you agree to our use of cookies.</span>
# <span class="cookies-eu-button-holder">
# <button class="cookies-eu-ok"> OK </button>
# <a class="cookies-eu-link" href="/pages/cookies-policy"> Learn more </a>
# </span>
# </div>
# </div>
# <script>
#             (function(d, s, id) {
#                 var js, fjs = d.getElementsByTagName(s)[0];
#                 if (d.getElementById(id)) return;
#                 js = d.createElement(s); js.id = id;
#                 js.src = "//connect.facebook.net/en_US/all.js#xfbml=1";
#                 fjs.parentNode.insertBefore(js, fjs);
#             }(document, 'script', 'facebook-jssdk'));
#         </script>
# <!-- Login dialog box -->
# <section class="form-dialog login" data-show="false">
# <header>
# <h3 class="login-title">My DLD - Sign in</h3>
# </header>
# <div class="inner">
# <div class="login-column-one">
# <form accept-charset="UTF-8" action="/people/sign_in" class="dialog-form" id="new_person" method="post"><div style="display:none"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="X33+08gHYUTmxcbkki8w9tbqkN1bhFuOL2snqPdad1Q="/></div>
# <fieldset>
# <legend class="semantic">Login credentials</legend>
# <div class="row">
# <input id="person_email" name="person[email]" pattern="[^@]+@[^@]+\.[a-zA-Z]{2,7}" placeholder="Email" required="required" type="text"/>
# </div>
# <div class="row">
# <input id="person_password" name="person[password]" placeholder="Password" required="required" type="password"/>
# </div>
# <a class="open-password-reminder" href="#" title="Forgot password?">
#               Forgot password?
#               <img alt="More arrow orange" class="more-arrow" src="/assets/more-arrow-orange-fcb5e90c5740a9e68683b3f5997b159f.png"/>
# </a> <div class="row">
# <div class="error-message"></div>
# </div>
# <div class="row">
# <div class="checkbox">
# <input name="person[remember_me]" type="hidden" value="0"/><input checked="checked" id="person_remember_me_login" name="person[remember_me]" type="checkbox" value="1"/>
# <label class="stay-logged-in" for="person_remember_me_login">Stay logged</label>
# </div>
# </div>
# <input id="after_sign_in_action" name="after_sign_in_action" type="hidden"/>
# <input class="red-button" name="commit" type="submit" value="Login"/>
# </fieldset>
# </form> </div>
# <div class="login-column-two">
# <a href="/people/auth/facebook">
# <img alt="Sign in facebook" class="provider-sign-in-button" src="/assets/sign_in_facebook-ea342ad61a1fdda69ef29ee9d11b04ba.png"/>
# </a> <a href="/people/auth/twitter">
# <img alt="Sign in twitter" class="provider-sign-in-button" src="/assets/sign_in_twitter-3a6e88be75a6214bf3a3449e83f3a010.png"/>
# </a> </div>
# <div class="login-vertical-line"></div>
# <div class="login-or">or</div>
# </div>
# <footer class="footer-clearfix">
# <p>
# <a class="open-new-account" href="#" title="New account">
#           New at DLD? <u>Create an account</u>
# </a> </p>
# </footer>
# </section>
# <!-- /Login dialog box -->
# <!-- Login dialog box -->
# <section class="form-dialog logout" data-show="false">
# <header>
# <h3>Logout</h3>
# </header>
# <div class="inner">
# <form accept-charset="UTF-8" action="/people/sign_out" class="dialog-form" method="post"><div style="display:none"><input name="utf8" type="hidden" value="✓"/><input name="_method" type="hidden" value="delete"/><input name="authenticity_token" type="hidden" value="X33+08gHYUTmxcbkki8w9tbqkN1bhFuOL2snqPdad1Q="/></div>
# <div class="row">
#         Do you really want to logout?
#       </div>
# <div class="row submit">
# <input name="commit" type="submit" value="Logout"/>
# <input class="logout-cancel" name="commit" type="submit" value="Cancel"/>
# </div>
# </form>
# </div>
# </section>
# <!-- /Login dialog box -->
# <!-- Password reminder dialog box -->
# <section class="form-dialog password-reminder">
# <header>
# <h3>Forgot Password</h3>
# </header>
# <div class="inner">
# <form accept-charset="UTF-8" action="/people/password" class="dialog-form" id="remind_password" method="post"><div style="display:none"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="X33+08gHYUTmxcbkki8w9tbqkN1bhFuOL2snqPdad1Q="/></div>
# <fieldset>
# <legend class="semantic">Email information</legend>
# <div class="row">
#           Please enter your email address and we will send you instructions to set a new password.
#         </div>
# <div class="row">
# <input id="email-input" name="person[email]" pattern="[^@]+@[^@]+\.[a-zA-Z]{2,7}" placeholder="Email" required="required" type="email"/>
# <input name="commit" type="submit" value="Send"/>
# <div class="error-message"></div>
# </div>
# </fieldset>
# </form> </div>
# </section>
# <!-- /Password reminder dialog box -->
# <!-- Change/confirm password dialog box -->
# <section class="form-dialog set-password" data-show="">
# <header>
# <h3><i class="icon icon-login"></i>Choose / Confirm new Password</h3>
# </header>
# <div class="inner">
# <form accept-charset="UTF-8" action="/users/password" class="dialog-form" data-remote="true" id="new_user" method="post"><div style="display:none"><input name="utf8" type="hidden" value="✓"/><input name="_method" type="hidden" value="put"/></div>
# <input id="user_reset_password_token" name="user[reset_password_token]" type="hidden"/>
# <fieldset>
# <legend class="semantic">Choose / Confirm new Password</legend>
# <div class="row">
# <label for="user_password">Please choose a new Password</label>
# <input id="user_password" name="user[password]" type="password"/>
# </div>
# <div class="row">
# <label for="user_password_confirmation">Please confirm new Password</label>
# <input id="user_password_confirmation" name="user[password_confirmation]" type="password"/>
# </div>
# <div class="row submit">
# <input name="commit" type="submit" value="Save password"/>
# <div class="error-message"></div>
# </div>
# </fieldset>
# </form> </div>
# </section>
# <!-- /Change/confirm password dialog box -->
# <!-- Password reminder dialog box -->
# <section class="form-dialog new-account general">
# <header>
# <h3>My DLD - Create Account</h3>
# </header>
# <div class="inner">
# <fieldset>
# <div>
# <a href="/people/sign_up">
# <div id="link-to-register">Sign up with Email</div>
# </a> </div>
# <hr/>
# <span class="or">or</span>
# <a href="/people/auth/facebook?register=true">
# <img alt="Sign up with facebook" class="provider-sign-in-button" src="/assets/sign_up_with_facebook-bc9a421cb938f7b360b782c0964b6c52.png"/>
# </a> <hr/>
# <span class="or">or</span>
# <a href="/people/auth/twitter?register=true">
# <img alt="Sign up with twitter" class="provider-sign-in-button" src="/assets/sign_up_with_twitter-d9605a61d809d3bd4b295a46dd6ee1e5.png"/>
# </a> </fieldset>
# </div>
# </section>
# <!-- /Password reminder dialog box -->
# <!-- Login dialog box -->
# <section class="form-dialog provider-login twitter" data-show="false">
# <header>
# <h3 class="login-title">My DLD - Sign in</h3>
# </header>
# <div class="inner">
# <p class="description">To link your Twitter account with your DLD profile, we need you to enter your DLD Email and Password. You only do this once.</p>
# <form accept-charset="UTF-8" action="/people/sign_in" class="dialog-form" id="new_person" method="post"><div style="display:none"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="X33+08gHYUTmxcbkki8w9tbqkN1bhFuOL2snqPdad1Q="/></div>
# <fieldset>
# <legend class="semantic"><span class="translation_missing" title="translation missing: en.layouts.shared.twitter_login_box.login_credentials">Login Credentials</span></legend>
# <input id="person_email" name="person[email]" pattern="[^@]+@[^@]+\.[a-zA-Z]{2,7}" placeholder="Email" required="required" type="text"/>
# <input id="person_password" name="person[password]" placeholder="Password" required="required" type="password"/>
# <div class="row">
# <div class="checkbox">
# <input name="person[remember_me]" type="hidden" value="0"/><input checked="checked" id="person_remember_me_twitter" name="person[remember_me]" type="checkbox" value="1"/>
# <label class="stay-logged-in" for="person_remember_me_twitter">Stay logged</label>
# </div>
# <div class="forgot-password">
# <a class="open-password-reminder" href="#" title="Forgot password?">
#                 Forgot password?
#                 <img alt="More arrow orange" class="more-arrow" src="/assets/more-arrow-orange-fcb5e90c5740a9e68683b3f5997b159f.png"/>
# </a> </div>
# </div>
# <div class="row">
# <div class="error-message"></div>
# </div>
# <input alt="Link with twitter" class="join-with-provider-button" src="/assets/link_with_twitter-147fc4059cfc4c5f8f858554cfe5317a.png" type="image"/>
# </fieldset>
# </form> </div>
# <footer class="footer-clearfix">
# <p>
# <a class="open-new-account" href="#" title="New account">
#           New at DLD? <u>Create an account</u>
# </a> </p>
# </footer>
# </section>
# <!-- /Login dialog box -->
# <script>
#   if($('section.form-dialog.provider-login.twitter').data("show")) {
#     $( '.form-dialog.provider-login.twitter' ).dialog({
#         width: 700,
#         modal: true
#     });
#   }
# </script>
# <!-- Login dialog box -->
# <section class="form-dialog provider-login facebook" data-show="false">
# <header>
# <h3 class="login-title">My DLD - Sign in</h3>
# </header>
# <div class="inner">
# <p class="description">To link your Facebook account with your DLD profile, we need you to enter your DLD Email and Password. You only do this once.</p>
# <form accept-charset="UTF-8" action="/people/sign_in" class="dialog-form" id="new_person" method="post"><div style="display:none"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="X33+08gHYUTmxcbkki8w9tbqkN1bhFuOL2snqPdad1Q="/></div>
# <fieldset>
# <legend class="semantic"><span class="translation_missing" title="translation missing: en.layouts.shared.facebook_login_box.login_credentials">Login Credentials</span></legend>
# <input id="person_email" name="person[email]" pattern="[^@]+@[^@]+\.[a-zA-Z]{2,7}" placeholder="Email" required="required" type="text"/>
# <input id="person_password" name="person[password]" placeholder="Password" required="required" type="password"/>
# <div class="row">
# <div class="checkbox">
# <input name="person[remember_me]" type="hidden" value="0"/><input checked="checked" id="person_remember_me_facebook" name="person[remember_me]" type="checkbox" value="1"/>
# <label class="stay-logged-in" for="person_remember_me_facebook">Stay logged</label>
# </div>
# <div class="forgot-password">
# <a class="open-password-reminder" href="#" title="Forgot password?">
#                 Forgot password?
#                 <img alt="More arrow orange" class="more-arrow" src="/assets/more-arrow-orange-fcb5e90c5740a9e68683b3f5997b159f.png"/>
# </a> </div>
# </div>
# <div class="row">
# <div class="error-message"></div>
# </div>
# <input alt="Link with facebook" class="join-with-provider-button" src="/assets/link_with_facebook-4144e1f681e0d96d704ce869c5641c72.png" type="image"/>
# </fieldset>
# </form> </div>
# <footer class="footer-clearfix">
# <p>
# <a class="open-new-account" href="#" title="New account">
#           New at DLD? <u>Create an account</u>
# </a> </p>
# </footer>
# </section>
# <!-- /Login dialog box -->
# <script>
#   if($('section.form-dialog.provider-login.facebook').data("show")) {
#     $( '.form-dialog.provider-login.facebook' ).dialog({
#       width: 700,
#       modal: true
#     });
#   }
# </script>
# <script>
#             $('.form-dialog.flash-message').dialog({
#                 modal: true,
#                 dialogClass: "flash-message",
#                 width: 400
#             });
#         </script>
# <section class="section section--no-margin full-width backgound-grey">
# <div class="visual visual--small" style="background-image: url('http://s3.amazonaws.com/dldwebsite-production/files/191/original/24814046285_719c78d2a9_k.jpg?1508789894')">
# </div>
# </section>
# <!-- Main content -->
# <section class="speakers-page search-page container backgound-grey">
# <section class="speakers search-page-container">
# <h1 class="bold"><span class="red">DLD</span> SPEAKERS</h1>
# <p id="no-speakers">Sorry, we don't have any speaker matching those search parameters.</p>
# <div class="speakers-list row search-page-list">
# <div class="filters-and-search col-md-12">
# <h2><span class="red">FILTER</span> <span>YOUR SEARCH</span></h2>
# <div class="speakers-search">
# <input id="speaker-first-name-search" name="q" placeholder="First Name" type="search"/>
# <input type="submit" value="Search"/>
# </div>
# <div class="speakers-search">
# <input id="speaker-last-name-search" name="q" placeholder="Last Name" type="search"/>
# <input type="submit" value="Search"/>
# </div>
# <div class="speakers-search">
# <input id="company" name="q" placeholder="Company" type="search"/>
# <input type="submit" value="Search"/>
# </div>
# <select id="conference" name="conference"><option value="">Conference</option><option value="312">DLD Munich 18</option>
# <option value="302">DLD Berlin 17</option>
# <option value="311">DLD Tel Aviv 17</option>
# <option value="296">DLD Europe 17</option>
# <option value="294">DLD Campus</option>
# <option value="264">DLD New York 17</option>
# <option value="235">DLD17</option>
# <option value="233">DLD Tel Aviv 16</option>
# <option value="232">DLDeurope 16</option>
# <option value="221">DLDsummer 16</option>
# <option value="185">DLDnyc 16</option>
# <option value="171">DLD16</option>
# <option value="170">DLD Tel Aviv 15</option>
# <option value="159">DLD Academy</option>
# <option value="151">DLDsummer 15</option>
# <option value="134">DLDnyc 15</option>
# <option value="67">DLD15</option>
# <option value="92">DLD Serpentine Breakfast 14</option>
# <option value="89">DLD Tel Aviv 14</option>
# <option value="58">DLDwomen14</option>
# <option value="63">DLDcities SFO</option>
# <option value="56">DLDnyc 14</option>
# <option value="38">TES 2014</option>
# <option value="40">DLD14 Chairmen &amp; Speaker Dinner</option>
# <option value="29">DLD14</option>
# <option value="28">DLD Tel Aviv 13</option>
# <option value="27">DLDcities London 13</option>
# <option value="22">DLDcities Rio 13</option>
# <option value="20">DLDwomen13</option>
# <option value="21">DLD Lunch with David Agus</option>
# <option value="17">DLD13</option>
# <option value="16">DLD Tel Aviv 12</option>
# <option value="36">DLD Bosphorus 12</option>
# <option value="14">DLDcities 12</option>
# <option value="12">DLDwomen12</option>
# <option value="13">DLD Moscow</option>
# <option value="9">DLD12</option>
# <option value="15">DLD Tel Aviv 11</option>
# <option value="11">DLDwomen11</option>
# <option value="8">DLD11</option>
# <option value="24">DLD Beijing 10</option>
# <option value="10">DLDwomen10</option>
# <option value="7">DLD10</option>
# <option value="6">DLD09</option>
# <option value="5">DLD08</option>
# <option value="4">DLD07</option>
# <option value="3">DLD06</option>
# <option value="2">DLD05</option></select>
# <select id="category" name="category"><option value="">Field of Operation</option><option value="Art, Design, Culture">Art, Design, Culture</option>
# <option value="Business (non digital), Professional Service">Business (non digital), Professional Service</option>
# <option value="Digital, Technology">Digital, Technology</option>
# <option value="Education">Education</option>
# <option value="Entertainment">Entertainment</option>
# <option value="Finance">Finance</option>
# <option value="Investor">Investor</option>
# <option value="Life &amp; Health">Life &amp; Health</option>
# <option value="Media">Media</option>
# <option value="Politics">Politics</option>
# <option value="Science">Science</option>
# <option value="Social">Social</option>
# <option value="Other">Other</option></select>
# <a class="header-link" id="clear-filters">
# <span class="red">CLEAR</span> <span>FILTERS</span>
# </a>
# </div>
# </div>
# <div class="div">
# <section class="speakers-gallery gallery js-masonry" data-masonry-options='{"itemSelector": ".speaker-item", "columnWidth": 150, "isAnimated": true, "fitWidth": true}'>
# </section>
# </div>
# </section></section></div>
# </div></body></html>
# <input id="conference_id" name="conference_id" type="hidden"/>
#
# <!-- /Main section -->
# <div class="spinner"></div>
# <script src="/assets/purelabs-5011697cf7f98d6d72742789f1bbfe2e.js"></script>
#
# <div id="footer">
# <footer class="relative-container">
# <div class="left-background hidden-xs" style="background-color: #FFF9AD;"></div>
# <div class="right-background hidden-xs" style="background-color: #a2c7f3;"></div>
# <div class="container relative-container">
# <div class="row">
# <div class="right-background-filler hidden-xs" style="background-color: #a2c7f3;"></div>
# <div class="col-sm-4 col-sm-push-8 newsletter" style="background-color: #a2c7f3;">
# <img alt="Nl icon" class="newsletter-logo center-block" src="/assets/digital1/icons/nl-icon-7998c69cd0cc680211ddecd671e30461.svg"/>
# <p class="bold text-center white">Get the DLD-Newsletter now!</p>
# <form action="//dld.us7.list-manage.com/subscribe/post?u=f1984f0145e957e5e55a9bc50&amp;id=1716ffa7b9" class="validate" method="post" name="mc-embedded-subscribe-form" novalidate="" onsubmit="Newsletter.closeNewsletterForm();" target="_blank">
# <input class="no-border" name="EMAIL" placeholder="Enter email address..." required="" type="email" value="">
# <input class="btn btn-orange" type="submit" value="Send">
# </input></input></form>
# </div>
# <div class="col-sm-8 col-sm-pull-4 links" style="background-color: #FFF9AD;">
# <p class="grey bold">Events around the world:</p>
# <ul class="list-inline text-uppercase events">
# <li><a class="orange bold" href="/events">Munich</a></li>
# <li><a class="orange bold" href="/events">New York</a></li>
# <li><a class="orange bold" href="/events">Brussels</a></li>
# <li><a class="orange bold" href="/events">Berlin</a></li>
# <li><a class="orange bold" href="/events">Tel Aviv</a></li>
# </ul>
# <br><br>
# <p class="grey bold">DLD Media:</p>
# <ul class="list-inline subpages">
# <li><a class="grey" href="/events">Archive</a></li>
# <li><a class="grey" href="/pages/contact">Contact</a></li>
# <li><a class="grey" href="/pages/dld-team">DLD Team</a></li>
# <li><a class="grey" href="/pages/imprint">Imprint</a></li>
# <li><a class="grey" href="//dld.us7.list-manage.com/subscribe/post?u=f1984f0145e957e5e55a9bc50&amp;id=1716ffa7b9" target="_blank">Newsletter</a></li>
# <li><a href="/pages/about-us">About</a></li>
# <li><a href="/pages/privacy-policy">Privacy Policy</a></li>
# </ul>
# <br><br>
# <p class="grey bold follow-us">Follow us</p>
# <ul class="list-inline social social-links">
# <li>
# <a href="https://www.facebook.com/DLDconference" target="_blank">
# <i class="icon icon-social icon-facebook-white"></i>
# </a> </li>
# <li>
# <a href="https://twitter.com/dldconference" target="_blank">
# <i class="icon icon-social icon-twitter-white"></i>
# </a> </li>
# <li>
# <a href="https://instagram.com/dldconference/" target="_blank">
# <i class="icon icon-social icon-instagram-white"></i>
# </a> </li>
# <li>
# <a href="https://www.youtube.com/user/DLDconference" target="_blank">
# <i class="icon icon-social icon-youtube-white"></i>
# </a> </li>
# </ul>
# </br></br></br></br></div>
# </div>
# </div>
# <div class="copyright grey text-center relative-container">© 2005-16 Hubert Burda Media Holding KG / DLD Media GmbH - All rights reserved.</div>
# </footer>
# </div>
